# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonPriemer/Kurs-AI/blob/main/Einf%C3%BChrung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basic Elemente der Programmiersprache Python**

# %% [markdown]
# *In dieser Einheit werden wir uns mit Elementen der Programmiersprache Python beschäftigen*

# %% [markdown]
# [Linktext](https://www.python.org/)

# %% [markdown]
# # Wichtige Elemente

# %% [markdown]
# 1. Variablen
# 2. Letters
# 3. Schleifen
# 4. Dictionaries und
# 5. Tupel
# 6. If-Anweisungen
# 7. Funktionen
# 8. Dateiverwaltung
# 9. Exceptions
